# %% [markdown]
# # Import

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

# %%
FILE_NAME = "PQ2MON - Orders - Weeks -1 to -109 (1).xls.xlsx"
DF = pd.read_excel(FILE_NAME)
DF.head(5)
# Out:
#   Client Grouping1     Customer Group Requested Mode  Priority  \
# 0        Corporate  3M Canada Company           ROAD  Standard
# 1        Corporate  3M Canada Company           ROAD  Standard
# 2        Corporate  3M Canada Company           ROAD  Standard
# 3        Corporate  3M Canada Company           ROAD  Standard
# 4        Corporate  3M Canada Company           ROAD  Standard
#
#   Requested Trailer Class Shipper Region3 Consignee Region3  \
# 0                     DRY          ON2TOR              PQ2S
# 1                     DRY          ON2TOR              PQ2S
# 2                     DRY          ON2TOR              PQ2S
# 3                     DRY          ON2TOR              PQ2S
# 4                     DRY          PQ2MON            USMWIA
#
#                       Lane ID - City to City Start Date Completion Date  \
# 0            MILTON,ON/ to DRUMMONDVILLE,PQ/ 2019-04-16      2019-04-18
# 1            MILTON,ON/ to DRUMMONDVILLE,PQ/ 2019-05-07      2019-05-09
# 2            MILTON,ON/ to DRUMMONDVILLE,PQ/ 2019-06-07      2019-06-10
# 3            MILTON,ON/ to DRUMMONDVILLE,PQ/ 2019-07-09      2019-07-11
# 4  STE THERESE,PQ/TE to PRAIRIE DU CHIEN,WI/ 2020-02-26      2020-03-02
#
#    Order #  Avg. Weekly Frequency
# 0  3790088                      0
# 1  3810953                      0
# 2  3841144                      0
# 3  3869973                      0
# 4  4066936                      0

# %%
DF
# Out:
#       Client Grouping1                  Customer Group Requested Mode  \
# 0            Corporate               3M Canada Company           ROAD
# 1            Corporate               3M Canada Company           ROAD
# 2            Corporate               3M Canada Company           ROAD
# 3            Corporate               3M Canada Company           ROAD
# 4            Corporate               3M Canada Company           ROAD
# ...                ...                             ...            ...
# 23864             Spot                    Traffic Tech           ROAD
# 23865             Spot                    Traffic Tech           ROAD
# 23866             Spot                    Traffic Tech           ROAD
# 23867             Spot                    Traffic Tech           ROAD
# 23868             Spot  WALHOM04 - WALMART FREIGHT PAY           ROAD
#
#        Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 0      Standard                     DRY          ON2TOR              PQ2S
# 1      Standard                     DRY          ON2TOR              PQ2S
# 2      Standard                     DRY          ON2TOR              PQ2S
# 3      Standard                     DRY          ON2TOR              PQ2S
# 4      Standard                     DRY          PQ2MON            USMWIA
# ...         ...                     ...             ...               ...
# 23864  Standard                     DRY          PQ2MON            BC2VAN
# 23865  Standard                  REEFER          PQ2MON            ABNEDM
# 23866  Standard                  REEFER          PQ2MON            ABNEDM
# 23867  Standard                  REEFER          PQ2MON            ABNEDM
# 23868  Standard                     DRY          PQ2MON             USSES
#
#                           Lane ID - City to City Start Date Completion Date  \
# 0                MILTON,ON/ to DRUMMONDVILLE,PQ/ 2019-04-16      2019-04-18
# 1                MILTON,ON/ to DRUMMONDVILLE,PQ/ 2019-05-07      2019-05-09
# 2                MILTON,ON/ to DRUMMONDVILLE,PQ/ 2019-06-07      2019-06-10
# 3                MILTON,ON/ to DRUMMONDVILLE,PQ/ 2019-07-09      2019-07-11
# 4      STE THERESE,PQ/TE to PRAIRIE DU CHIEN,WI/ 2020-02-26      2020-03-02
# ...                                          ...        ...             ...
# 23864              ST LAURENT,PQ/IL to DELTA,BC/ 2020-06-18      2020-06-22
# 23865           BOUCHERVILLE,PQ/ to EDMONTON,AB/ 2020-02-12      2020-02-18
# 23866           BOUCHERVILLE,PQ/ to EDMONTON,AB/ 2020-02-12      2020-02-20
# 23867           BOUCHERVILLE,PQ/ to EDMONTON,AB/ 2020-02-13      2020-02-18
# 23868         MONTREAL NORD,PQ/ to DAVENPORT,FL/ 2021-04-09      2021-04-13
#
#        Order #  Avg. Weekly Frequency
# 0      3790088                      0
# 1      3810953                      0
# 2      3841144                      0
# 3      3869973                      0
# 4      4066936                      0
# ...        ...                    ...
# 23864  4192727                      0
# 23865  4074001                      0
# 23866  4073978                      0
# 23867  4074019                      0
# 23868  4477471                      0
#
# [23869 rows x 12 columns]

# %%
DAYS_0 = pd.Timedelta(days=0)
DAYS_1 = pd.Timedelta(days=1)
DAYS_14 = pd.Timedelta(days=14)

# %% [markdown]
# # Helper Functions

# %% [markdown]
# ## Clean Data

# %%
# Clean the irrelevant columns, only keeping the rows that has PQ data
# internal are orders that starts and completes within the PQ region itself.
# external are orders that goes from anyhwere in PQ to other region and vice versa
def get_df_clean(df,select=None,drop=["Customer Group","Requested Mode","Order #","Avg. Weekly Frequency","Lane ID - City to City","Client Grouping1"]):
    df_PQ = df[df['Shipper Region3'].str.contains('PQ')|df['Consignee Region3'].str.contains('PQ')].drop(columns=drop)
    df_PQ.loc[:,'Shipper Region3'].fillna("UNKNOWN",inplace=True)
    df_PQ.loc[:,'Consignee Region3'].fillna("UNKNOWN",inplace=True)
    df_PQ_int = df_PQ[df_PQ["Shipper Region3"].str.contains('PQ') & df_PQ["Consignee Region3"].str.contains('PQ')]
    df_PQ_ext = df_PQ.drop(index=df_PQ_int.index)
    if select == "internal": return df_PQ_int
    elif select == "external": return df_PQ_ext
    else: return df_PQ

# %%
# Demo
DF_CLEAN = get_df_clean(DF)
DF_CLEAN
# Out:
#        Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 0      Standard                     DRY          ON2TOR              PQ2S
# 1      Standard                     DRY          ON2TOR              PQ2S
# 2      Standard                     DRY          ON2TOR              PQ2S
# 3      Standard                     DRY          ON2TOR              PQ2S
# 4      Standard                     DRY          PQ2MON            USMWIA
# ...         ...                     ...             ...               ...
# 23864  Standard                     DRY          PQ2MON            BC2VAN
# 23865  Standard                  REEFER          PQ2MON            ABNEDM
# 23866  Standard                  REEFER          PQ2MON            ABNEDM
# 23867  Standard                  REEFER          PQ2MON            ABNEDM
# 23868  Standard                     DRY          PQ2MON             USSES
#
#       Start Date Completion Date
# 0     2019-04-16      2019-04-18
# 1     2019-05-07      2019-05-09
# 2     2019-06-07      2019-06-10
# 3     2019-07-09      2019-07-11
# 4     2020-02-26      2020-03-02
# ...          ...             ...
# 23864 2020-06-18      2020-06-22
# 23865 2020-02-12      2020-02-18
# 23866 2020-02-12      2020-02-20
# 23867 2020-02-13      2020-02-18
# 23868 2021-04-09      2021-04-13
#
# [23074 rows x 6 columns]

# %%
df_PQ_ext = get_df_clean(DF,'external')
print(len(df_PQ_ext))
df_PQ_ext.head(5)
# Out:
# 22364
#    Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 0  Standard                     DRY          ON2TOR              PQ2S
# 1  Standard                     DRY          ON2TOR              PQ2S
# 2  Standard                     DRY          ON2TOR              PQ2S
# 3  Standard                     DRY          ON2TOR              PQ2S
# 4  Standard                     DRY          PQ2MON            USMWIA
#
#   Start Date Completion Date
# 0 2019-04-16      2019-04-18
# 1 2019-05-07      2019-05-09
# 2 2019-06-07      2019-06-10
# 3 2019-07-09      2019-07-11
# 4 2020-02-26      2020-03-02

# %%
df_PQ_int = get_df_clean(DF,'internal')
print(len(df_PQ_int))
df_PQ_int.head(5)
# Out:
# 710
#     Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 11  Standard                     DRY          PQ2OTT            PQ2MON
# 12  Standard                     DRY          PQ2OTT            PQ2MON
# 13  Standard                     DRY          PQ2OTT            PQ2MON
# 14  Standard                     DRY          PQ2OTT            PQ2MON
# 15  Standard                     DRY          PQ2OTT            PQ2MON
#
#    Start Date Completion Date
# 11 2019-10-25      2019-10-28
# 12 2019-10-07      2019-10-09
# 13 2019-11-08      2019-11-12
# 14 2019-12-03      2019-12-03
# 15 2019-12-30      2020-01-03

# %% [markdown]
# ## Getting the statistics

# %%
# Get the counts for a schedule, such as inbound and out bound figures. Also calculates the imbalance levels
def get_df_count(df,start_date=None,end_date=None,fill_missing=False,region='PQ'):
    if start_date == None: start_date = get_earliest(df,'Start Date')
    if end_date == None: end_date = get_latest(df,'Completion Date')
    if region == 'any': region = ''
    df_out = df[df['Shipper Region3'].str.startswith(region)]['Start Date'].value_counts().sort_index(axis=0)
    df_in = df[df['Consignee Region3'].str.startswith(region)]['Completion Date'].value_counts().sort_index(axis=0)
    df_count = pd.concat([df_out, df_in],axis=1).fillna(0, downcast='infer').rename(columns={"Start Date": "Outbound", "Completion Date": "Inbound"})
    if fill_missing and start_date and end_date:
        df_count = pd.DataFrame(index=get_dates(start_date,end_date)).join(df_count,how='outer').fillna(0)  
    df_count = df_count[start_date:end_date]
    df_count["Imbalance"] = df_count["Inbound"] - df_count["Outbound"]
    df_count["cImbalance"] = df_count["Imbalance"].cumsum()
    return df_count

# Get the imbalance level of the date
def get_imb(df,date,col="Imbalance"):
    if (col == "Imbalance" or col == "cImbalance") and date in df.index:
        return df.loc[date,col]
    
def get_dates(start_date,end_date):
    if type(start_date) == pd.Timestamp and type(end_date) == pd.Timestamp:
        return [start_date + i*DAYS_1 for i in range(int((end_date-start_date).days+1))]
    else: return []

def get_earliest(df,col=["Start Date","Completion Date"],region='PQ'):
    region = '' if region == 'any' else region
    if col == ["Start Date","Completion Date"]:
        return df.loc[:,col].min().min()
    elif col == 'Start Date':
        cond = df['Shipper Region3'].str.startswith(region) 
        return df[cond].loc[:,col].min()
    elif col == 'Completion Date':
        cond = df['Consignee Region3'].str.startswith(region) 
        return df[cond].loc[:,col].min()
    
def get_latest(df,col=["Start Date","Completion Date"],region='PQ'):
    region = '' if region == 'any' else region
    if col == ["Start Date","Completion Date"]:
        return df.loc[:,col].max().max()
    elif col == 'Start Date':
        cond = df['Shipper Region3'].str.startswith(region) 
        return df[cond].loc[:,col].max()
    elif col == 'Completion Date':
        cond = df['Consignee Region3'].str.startswith(region) 
        return df[cond].loc[:,col].max()

# %%
#Demo
DF_COUNT = get_df_count(DF_CLEAN)
DF_COUNT
# Out:
#             Outbound  Inbound  Imbalance  cImbalance
# 2019-03-13         1        0         -1          -1
# 2019-03-19         2        0         -2          -3
# 2019-03-20         2        0         -2          -5
# 2019-03-21         1        0         -1          -6
# 2019-03-22        12        0        -12         -18
# ...              ...      ...        ...         ...
# 2021-04-20        21       20         -1         251
# 2021-04-21        12       25         13         264
# 2021-04-22        10       30         20         284
# 2021-04-23        11       24         13         297
# 2021-04-24         1        8          7         304
#
# [769 rows x 4 columns]

# %%
#Demo
start_date = pd.Timestamp(2019,3,13,0)
end_date = pd.Timestamp(2019,3,19,0)

# df_count = get_df_count(DF_CLEAN,start_date,end_date)
df_count = get_df_count(DF_CLEAN,start_date,end_date,fill_missing=True)
print(get_imb(df_count,start_date))
df_count
# Out:
# -1.0
#             Outbound  Inbound  Imbalance  cImbalance
# 2019-03-13       1.0      0.0       -1.0        -1.0
# 2019-03-14       0.0      0.0        0.0        -1.0
# 2019-03-15       0.0      0.0        0.0        -1.0
# 2019-03-16       0.0      0.0        0.0        -1.0
# 2019-03-17       0.0      0.0        0.0        -1.0
# 2019-03-18       0.0      0.0        0.0        -1.0
# 2019-03-19       2.0      0.0       -2.0        -3.0

# %%
#Demo
start_date = pd.Timestamp(2019,3,13,0)
end_date = pd.Timestamp(2019,3,19,0)

get_dates(start_date,end_date)
# Out:
# [Timestamp('2019-03-13 00:00:00'),
#  Timestamp('2019-03-14 00:00:00'),
#  Timestamp('2019-03-15 00:00:00'),
#  Timestamp('2019-03-16 00:00:00'),
#  Timestamp('2019-03-17 00:00:00'),
#  Timestamp('2019-03-18 00:00:00'),
#  Timestamp('2019-03-19 00:00:00')]

# %%
#Demo
df = DF_CLEAN

get_earliest(df)
# get_earliest(df,'Start Date')
# get_earliest(df,'Completion Date')
# get_latest(df)
# get_latest(df,'Completion Date')
# Out:
# Timestamp('2019-01-31 00:00:00')

# %%
# Get all the orders that start and/or completes on a specific day
def get_df_day(df,date,col=['Start Date','Completion Date'],region='PQ'):
    if region == 'any': region = ''
    cond_out = df['Shipper Region3'].str.startswith(region) & (df['Start Date'] == date)
    cond_in = df['Consignee Region3'].str.startswith(region) & (df['Completion Date'] == date)
    if col == 'Start Date': return df[cond_out]
    elif col == 'Completion Date': return df[cond_in]
    elif col == ['Start Date','Completion Date']: return df[cond_out | cond_in]

# Get all orders that starts and/or completes in a specific time span
def get_df_span(df,start_date=None,end_date=None,col=['Start Date','Completion Date'],region='PQ'):
    if start_date == None: start_date = get_earliest(df)
    if end_date == None: end_date = get_latest(df)
    if region == 'any': region = ''
    cond_out = df['Shipper Region3'].str.startswith(region) & (df["Start Date"] >= start_date) & (df["Start Date"] <= end_date)
    cond_in = df['Consignee Region3'].str.startswith(region) & (df["Completion Date"] >= start_date) & (df["Completion Date"] <= end_date)
    if col == 'Start Date': return df[cond_out]
    elif col == 'Completion Date': return df[cond_in]
    elif col == ['Start Date','Completion Date']: return df[cond_out | cond_in]

# %%
get_df_day(DF_CLEAN,pd.Timestamp(2020,1,15,0),region="US")
# Out:
#        Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 1048   Standard                  HEATER          USSCAT            PQ2MON
# 4071   Standard                  REEFER          USSWCS            PQ2MON
# 4474   Standard                  REEFER          USEASE            PQ2MON
# 5119   Standard                  REEFER          USSWCS            PQ2MON
# 5120   Standard                  REEFER          USSWCS            PQ2MON
# 8478   Standard                     DRY          USMEON            PQ2MON
# 9772   Standard                     DRY            PQ2S            USMEIS
# 12556  Standard                     DRY            PQ2S            USNWWA
# 13172  Standard                     DRY           USEAC            PQ2MON
# 14385  Standard                  HEATER          USWIGR            PQ2MON
# 14386  Standard                  HEATER          USWIGR            PQ2MON
# 14602  Standard                     DRY          USEASE            PQ2MON
# 14603  Standard                     DRY          USEASE            PQ2MON
# 16078  Standard                     DRY          PQ2MON            USMWIA
# 18433  Standard                     DRY          PQ2MON            USILCH
#
#       Start Date Completion Date
# 1048  2020-01-15      2020-01-17
# 4071  2020-01-15      2020-01-21
# 4474  2020-01-15      2020-01-16
# 5119  2020-01-15      2020-01-19
# 5120  2020-01-15      2020-01-22
# 8478  2020-01-15      2020-01-17
# 9772  2020-01-13      2020-01-15
# 12556 2020-01-08      2020-01-15
# 13172 2020-01-15      2020-01-16
# 14385 2020-01-15      2020-01-17
# 14386 2020-01-15      2020-01-17
# 14602 2020-01-15      2020-01-16
# 14603 2020-01-15      2020-01-16
# 16078 2020-01-13      2020-01-15
# 18433 2020-01-13      2020-01-15

# %%
# Aside: why I have to use .min().min()

# %%
df = DF_CLEAN
df.loc[:,"Start Date":"Completion Date"].min()
# Out:
# Start Date        2019-01-31
# Completion Date   2019-03-24
# dtype: datetime64[ns]

# %%
df.loc[:,"Start Date":"Completion Date"].min().min()
# Out:
# Timestamp('2019-01-31 00:00:00')

# %%
# Aside: How to view any region
df = DF_CLEAN
# date = get_earliest(df)
# get_df_day(df,date,region='any')

date = get_latest(df)
get_df_day(df,date,region='ON')
# Out:
#         Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 16576   Standard                  REEFER          PQ2MON            ON2TOR
# 19304  Expedited                     DRY          PQ2MON            ON2TOR
#
#       Start Date Completion Date
# 16576 2021-04-23      2021-04-24
# 19304 2021-04-23      2021-04-24

# %%
# Demo
df = DF_CLEAN
date1 = pd.Timestamp(2020,1,1,0)
date2 = pd.Timestamp(2020,1,7,0)

get_df_day(df,date2).sort_values(by=["Start Date","Completion Date"])
# get_df_day(df,date2,'Completion Date')
# get_df_day(df,date2,'Start Date')
# Out:
#         Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 14726   Standard                     DRY          USMWMO            PQ2MON
# 4068    Standard                  REEFER          USSWCS            PQ2MON
# 5490    Standard                  HEATER           USSEE            PQ2QUE
# 13780  Expedited                     DRY          ABSCAL            PQ2MON
# 14073   Standard                     DRY          SK2SAS              PQ2S
# 58      Standard                     DRY          USMNMI              PQ2S
# 10730   Standard                     DRY          ON2TOR            PQ2MON
# 2148    Standard                  HEATER          ON2TOR            PQ2MON
# 6210    Standard                     DRY          ON2TOR            PQ2MON
# 7123    Standard                     DRY          ON2TOR            PQ2MON
# 7124    Standard                     DRY          ON2TOR            PQ2MON
# 7972    Standard                  REEFER          PQ2MON            PQ2MON
# 12833   Standard                  REEFER          USEASE            PQ2MON
# 13071   Standard                     DRY           USEAC            PQ2MON
# 13072   Standard                     DRY           USEAC            PQ2MON
# 14865  Expedited                     DRY          ON2TOR            PQ2MON
# 15359   Standard                     DRY          USEASE            PQ2MON
# 1351    Standard                  REEFER          ON2TOR            PQ2MON
# 6211    Standard                     DRY          ON2TOR            PQ2MON
# 20770   Standard                  REEFER          PQ2MON            ON2TOR
# 13475  Expedited                  HEATER          PQ2MON            ABSCAL
# 17500  Expedited                     DRY          PQ2MON            MB2WIN
# 20708   Standard                  REEFER          PQ2MON              ON2N
# 21656   Standard                     DRY          PQ2MON              ON2S
# 9770    Standard                     DRY            PQ2S            USMEIS
# 13457  Expedited                     DRY          PQ2MON            ABSCAL
# 19335   Standard                     DRY          PQ2MON            USILCH
# 19336   Standard                     DRY          PQ2MON            USILCH
# 22821  Expedited                  HEATER          PQ2MON            ABSCAL
# 13735   Standard                     DRY            PQ2S            MB2ONE
# 16546   Standard                     DRY          PQ2MON            USEASW
# 21359   Standard                  REEFER          PQ2MON            MB2WIN
# 19507   Standard                  REEFER          PQ2MON            ABNEDM
#
#       Start Date Completion Date
# 14726 2019-12-27      2020-01-07
# 4068  2019-12-31      2020-01-07
# 5490  2020-01-02      2020-01-07
# 13780 2020-01-02      2020-01-07
# 14073 2020-01-02      2020-01-07
# 58    2020-01-03      2020-01-07
# 10730 2020-01-05      2020-01-07
# 2148  2020-01-06      2020-01-07
# 6210  2020-01-06      2020-01-07
# 7123  2020-01-06      2020-01-07
# 7124  2020-01-06      2020-01-07
# 7972  2020-01-06      2020-01-07
# 12833 2020-01-06      2020-01-07
# 13071 2020-01-06      2020-01-07
# 13072 2020-01-06      2020-01-07
# 14865 2020-01-06      2020-01-07
# 15359 2020-01-06      2020-01-07
# 1351  2020-01-07      2020-01-07
# 6211  2020-01-07      2020-01-07
# 20770 2020-01-07      2020-01-07
# 13475 2020-01-07      2020-01-08
# 17500 2020-01-07      2020-01-08
# 20708 2020-01-07      2020-01-08
# 21656 2020-01-07      2020-01-08
# 9770  2020-01-07      2020-01-09
# 13457 2020-01-07      2020-01-09
# 19335 2020-01-07      2020-01-09
# 19336 2020-01-07      2020-01-09
# 22821 2020-01-07      2020-01-09
# 13735 2020-01-07      2020-01-10
# 16546 2020-01-07      2020-01-10
# 21359 2020-01-07      2020-01-10
# 19507 2020-01-07      2020-01-13

# %%
# Demo
df = DF_CLEAN
date1 = pd.Timestamp(2020,1,1,0)
date2 = pd.Timestamp(2020,1,7,0)

get_df_span(df,date1,date2)
# get_df_span(df,start_date=None,end_date=date2,how='inner')
# get_df_span(df,date1,date2,'inner')
# Out:
#         Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 15      Standard                     DRY          PQ2OTT            PQ2MON
# 58      Standard                     DRY          USMNMI              PQ2S
# 619     Standard                     DRY          PQ2MON            USMEON
# 640     Standard                     DRY          PQ2MON            USMEON
# 650     Standard                     DRY          PQ2MON            USMEON
# ...          ...                     ...             ...               ...
# 22182  Expedited                     DRY          PQ2MON            ABNEDM
# 22183  Expedited                     DRY          PQ2MON            ABNEDM
# 22821  Expedited                  HEATER          PQ2MON            ABSCAL
# 22917  Expedited                  HEATER          PQ2MON            MB2WIN
# 23270   Standard                     DRY          PQ2MON            USSCTN
#
#       Start Date Completion Date
# 15    2019-12-30      2020-01-03
# 58    2020-01-03      2020-01-07
# 619   2020-01-06      2020-01-08
# 640   2020-01-03      2020-01-06
# 650   2020-01-06      2020-01-08
# ...          ...             ...
# 22182 2020-01-04      2020-01-06
# 22183 2020-01-06      2020-01-09
# 22821 2020-01-07      2020-01-09
# 22917 2020-01-03      2020-01-05
# 23270 2020-01-03      2020-01-08
#
# [146 rows x 6 columns]

# %%
# Get a number of orders that can be moved to other days
def get_cand_orders(df,date,col=['Start Date','Completion Date'],num_orders=None):
    df_cand = get_df_day(df,date,col)
    if num_orders == None: num_orders = len(df_cand)
    else: num_orders = int(min(len(df_cand),num_orders))
    return df_cand.iloc[:num_orders].sort_values(by=col)

# %%
# get_cand_orders(df_resched,fr,'Start Date',num_orders)

# %%
# Demo
df = DF_CLEAN
date1 = pd.Timestamp(2020,1,1,0)
date2 = pd.Timestamp(2020,1,7,0)

# get_cand_orders(df,date2) # Get all the candidate orders
get_cand_orders(df,date2,'Start Date',8) # Get a certain number of the candidate orders on that day
# Out:
#         Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 9770    Standard                     DRY            PQ2S            USMEIS
# 13457  Expedited                     DRY          PQ2MON            ABSCAL
# 13475  Expedited                  HEATER          PQ2MON            ABSCAL
# 13735   Standard                     DRY            PQ2S            MB2ONE
# 16546   Standard                     DRY          PQ2MON            USEASW
# 17500  Expedited                     DRY          PQ2MON            MB2WIN
# 19335   Standard                     DRY          PQ2MON            USILCH
# 19336   Standard                     DRY          PQ2MON            USILCH
#
#       Start Date Completion Date
# 9770  2020-01-07      2020-01-09
# 13457 2020-01-07      2020-01-09
# 13475 2020-01-07      2020-01-08
# 13735 2020-01-07      2020-01-10
# 16546 2020-01-07      2020-01-10
# 17500 2020-01-07      2020-01-08
# 19335 2020-01-07      2020-01-09
# 19336 2020-01-07      2020-01-09

# %%
# Actually reschedule an order in the scheduling table (by overwriting the date in column col)
# Returns the modified schedule and the updated counts
def move(df,index,to_date,col='Start Date'):
    df_resched = df.copy()
    df_resched.loc[index,col] = to_date
    return df_resched

# %%
# Demo
df = DF_CLEAN
index = df.index[5]
to_date = df.loc[index,'Start Date'] + DAYS_1

df_resched = move(df,index,to_date,'Start Date')
print(df.loc[index],'\n')
print(df_resched.loc[index])
# Out:
# Priority                              Standard
# Requested Trailer Class                    DRY
# Shipper Region3                         PQ2MON
# Consignee Region3                       USMWIA
# Start Date                 2020-04-08 00:00:00
# Completion Date            2020-04-10 00:00:00
# Name: 5, dtype: object
#
# Priority                              Standard
# Requested Trailer Class                    DRY
# Shipper Region3                         PQ2MON
# Consignee Region3                       USMWIA
# Start Date                 2020-04-09 00:00:00
# Completion Date            2020-04-10 00:00:00
# Name: 5, dtype: object

# %%
# Get the bound (earliest/latest) dates in between which an order have to start and complete.
# By default the assumption would be that the order must start in between 14 days prior to 
# originally scheduled all the way to 0 days before; and must completes within 1 day prior to 1 day after
# originally scheduled.
# Because of this, we based the completion date on the date in the ORIGINAL schedule (i.e DF_CLEAN)
def get_bound_dates(index):
    df = DF_CLEAN
    compl_date = df.loc[index,'Completion Date']
    e_start,l_start = compl_date - DAYS_14, compl_date - DAYS_0
    e_compl,l_compl = compl_date - DAYS_1, compl_date + DAYS_1
    return {"e_start":e_start,"l_start":l_start,"e_compl":e_compl,"l_compl":l_compl}

# Checks if an order violates any boundaries, especially after rescheduled
def check_bound_violations(df,index,check_start=True,check_compl=True):
    start = df.loc[index,'Start Date'] 
    compl = df.loc[index,'Completion Date']
    e_start,l_start,e_compl,l_compl = get_bound_dates(index).values()
    start_viol = check_start and (start < e_start or start > l_start)
    compl_viol = check_compl and (compl < e_compl or compl > l_compl)
    return start_viol or compl_viol

# %%
# Demo
df = DF_CLEAN
index = df.index[5]

print(df.loc[index,'Start Date':'Completion Date'],'\n')
print("Violation: ",check_bound_violations(df,index))
get_bound_dates(index)
# Out:
# Start Date         2020-04-08 00:00:00
# Completion Date    2020-04-10 00:00:00
# Name: 5, dtype: object
#
# Violation:  False
# {'e_start': Timestamp('2020-03-27 00:00:00'),
#  'l_start': Timestamp('2020-04-10 00:00:00'),
#  'e_compl': Timestamp('2020-04-09 00:00:00'),
#  'l_compl': Timestamp('2020-04-11 00:00:00')}

# %%
# Demo
df = DF_CLEAN
index = df.index[5]
to_date = df.loc[index,'Start Date'] + 3*DAYS_1

df_resched = move(df,index,to_date,'Start Date')
print(df.loc[index],'\n')
print(df_resched.loc[index])

print("Violation: ",check_bound_violations(df_resched,index))
# Out:
# Priority                              Standard
# Requested Trailer Class                    DRY
# Shipper Region3                         PQ2MON
# Consignee Region3                       USMWIA
# Start Date                 2020-04-08 00:00:00
# Completion Date            2020-04-10 00:00:00
# Name: 5, dtype: object
#
# Priority                              Standard
# Requested Trailer Class                    DRY
# Shipper Region3                         PQ2MON
# Consignee Region3                       USMWIA
# Start Date                 2020-04-11 00:00:00
# Completion Date            2020-04-10 00:00:00
# Name: 5, dtype: object
# Violation:  True

# %%
# Get orders that have the same values in columns in col
# Used mostly to determine the shortest/longest expected time for order of the same type
def get_df_similar_orders(df,index,col=["Priority","Requested Trailer Class","Shipper Region3","Consignee Region3"]):
    order = df.loc[index,col]
    df_dup = df.loc[:,col]
    df_dup = df_dup[df_dup == order].dropna()
    return df.loc[df_dup.index,:]

# %%
# Demo
df = DF_CLEAN
index = df.index[5]

print(df.loc[index],'\n')
get_df_similar_orders(df,index)
# get_df_similar_orders(df,index,col=["Shipper Region3","Consignee Region3"]) # Only getting orders with same Shipper Region and Consignee Region
# Out:
# Priority                              Standard
# Requested Trailer Class                    DRY
# Shipper Region3                         PQ2MON
# Consignee Region3                       USMWIA
# Start Date                 2020-04-08 00:00:00
# Completion Date            2020-04-10 00:00:00
# Name: 5, dtype: object
#        Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 4      Standard                     DRY          PQ2MON            USMWIA
# 5      Standard                     DRY          PQ2MON            USMWIA
# 6      Standard                     DRY          PQ2MON            USMWIA
# 7      Standard                     DRY          PQ2MON            USMWIA
# 8      Standard                     DRY          PQ2MON            USMWIA
# 9      Standard                     DRY          PQ2MON            USMWIA
# 16075  Standard                     DRY          PQ2MON            USMWIA
# 16076  Standard                     DRY          PQ2MON            USMWIA
# 16077  Standard                     DRY          PQ2MON            USMWIA
# 16078  Standard                     DRY          PQ2MON            USMWIA
# 16079  Standard                     DRY          PQ2MON            USMWIA
# 16080  Standard                     DRY          PQ2MON            USMWIA
# 16081  Standard                     DRY          PQ2MON            USMWIA
# 16082  Standard                     DRY          PQ2MON            USMWIA
# 16083  Standard                     DRY          PQ2MON            USMWIA
# 16084  Standard                     DRY          PQ2MON            USMWIA
# 16085  Standard                     DRY          PQ2MON            USMWIA
# 16086  Standard                     DRY          PQ2MON            USMWIA
# 16087  Standard                     DRY          PQ2MON            USMWIA
# 16088  Standard                     DRY          PQ2MON            USMWIA
# 16089  Standard                     DRY          PQ2MON            USMWIA
# 16090  Standard                     DRY          PQ2MON            USMWIA
# 16091  Standard                     DRY          PQ2MON            USMWIA
# 16092  Standard                     DRY          PQ2MON            USMWIA
# 16093  Standard                     DRY          PQ2MON            USMWIA
# 16094  Standard                     DRY          PQ2MON            USMWIA
# 16095  Standard                     DRY          PQ2MON            USMWIA
# 16096  Standard                     DRY          PQ2MON            USMWIA
#
#       Start Date Completion Date
# 4     2020-02-26      2020-03-02
# 5     2020-04-08      2020-04-10
# 6     2020-05-11      2020-05-13
# 7     2020-12-01      2020-12-04
# 8     2021-03-11      2021-03-14
# 9     2021-03-17      2021-03-22
# 16075 2019-12-03      2019-12-06
# 16076 2019-12-18      2019-12-20
# 16077 2019-12-29      2020-01-02
# 16078 2020-01-13      2020-01-15
# 16079 2020-01-22      2020-01-27
# 16080 2020-02-11      2020-02-13
# 16081 2020-02-17      2020-02-19
# 16082 2020-03-04      2020-03-06
# 16083 2020-03-23      2020-03-25
# 16084 2020-04-01      2020-04-06
# 16085 2020-04-17      2020-04-21
# 16086 2020-11-03      2020-11-05
# 16087 2020-11-16      2020-11-18
# 16088 2020-12-15      2020-12-17
# 16089 2020-12-27      2020-12-30
# 16090 2021-01-13      2021-01-15
# 16091 2021-01-20      2021-01-22
# 16092 2021-02-02      2021-02-04
# 16093 2021-02-10      2021-02-12
# 16094 2021-02-24      2021-02-26
# 16095 2021-03-31      2021-04-02
# 16096 2021-04-13      2021-04-19

# %%
# Records the changes in days made to the "Start Date" and "Completion Date" of the original schedule
def get_df_sched_diff(df_sched,df_resched):
    df = df_resched.loc[:,"Start Date":"Completion Date"] - df_sched.loc[:,"Start Date":"Completion Date"]
    return df[df != DAYS_0].dropna(how='all').fillna(DAYS_0)

def get_df_count_diff(df_count,df_recount):
    df = df_recount.loc[:,:] - df_count.loc[:,:]
    return df[df != 0].dropna(how='all').fillna(0)

# %%
# Demo
date1 = pd.Timestamp(2021,1,1,0)

df = DF_CLEAN.copy()
index = df.index[5]
df_resched = move(df,index,date1,'Completion Date')

print(df.loc[index])
print(df_resched.loc[index])
get_df_sched_diff(df,df_resched)
# Out:
# Priority                              Standard
# Requested Trailer Class                    DRY
# Shipper Region3                         PQ2MON
# Consignee Region3                       USMWIA
# Start Date                 2020-04-08 00:00:00
# Completion Date            2020-04-10 00:00:00
# Name: 5, dtype: object
# Priority                              Standard
# Requested Trailer Class                    DRY
# Shipper Region3                         PQ2MON
# Consignee Region3                       USMWIA
# Start Date                 2020-04-08 00:00:00
# Completion Date            2021-01-01 00:00:00
# Name: 5, dtype: object
#   Start Date Completion Date
# 5     0 days        266 days

# %%
date1 = pd.Timestamp(2021,1,1,0)

get_df_day(df_resched,date1)
# get_df_count(df_resched,date1,date1+DAYS_1)

# df_count[df_count != df_recount].dropna(how='all')
# Out:
#         Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 2695   Expedited                     DRY          BC2VAN            PQ2MON
# 2696   Expedited                     DRY          BC2VAN            PQ2MON
# 10173   Standard                     DRY          PQ2MON            ABNEDM
#
#       Start Date Completion Date
# 2695  2020-12-29      2021-01-01
# 2696  2020-12-30      2021-01-01
# 10173 2021-01-01      2021-01-07

# %%
get_df_count(df_resched,date1-3*DAYS_1,date1+3*DAYS_1)
# Out:
#             Outbound  Inbound  Imbalance  cImbalance
# 2020-12-29        18       17         -1          -1
# 2020-12-30        21       18         -3          -4
# 2020-12-31        15       23          8           4
# 2021-01-01         1        2          1           5
# 2021-01-02        12       10         -2           3
# 2021-01-03         8        3         -5          -2
# 2021-01-04        20       23          3           1

# %% [markdown]
# # Algorithm

# %% [markdown]
# ## Pseudo Code

# %% [markdown]
# Note:
#
#     imb = inbound - outbound (how many spare trailers)
#     imb > 0 : there are spare trailers for the day (that can otherwise be utilized)
#     imb < 0 : there are shortage of trailers for the day (we likely have to hire outside trailers)
#     imb = 0 : there are just enough trailers
#     day.imb < next.imb : there are less spare trailers today than tomorrow/ or there are more of a shortage
#     day.imb > next.imb : there are more spare trailers today than tomorrow/ or there are less of a shortage

# %% [markdown]
# Idea:
# ```
# for date in all_days:
#     next = day.next
#     if (date.imb > 0):
#     # if we have spare trailers today
#         if (next.imb > date.imb):
#         # if tomorrow we have even more spare trailers than today
#             #
#             # We defer some outbound order today to tomorrow so we can utilize tomorrow's larger spare trailers
#             #
#         elif (next.imb < date.imb):
#         # if tomorrow there's less spare trailers, or even a shortage
#             #
#             # We take in tomorrow outbound orders so we can utilize today's larger spare trailers
#             #
#
#     elif (date.imb < 0):
#     # if we are short of trailers today:
#         if (next.imb > date.imb):
#         # if we are less short of trailers tomorrow, or even have spare trailers
#             #
#             # We ask some inbound order to arrive sooner (today, as opposed to tomorrow)
#             #
#         elif (next.imb < date.imb):
#         # if we are even more short of trailers tomorrow
#             #
#             # we allow some inbound order today to complete tomorrow
#             #
#
# ```

# %% [markdown]
# ## Code

# %%
def get_df_rescheduled(df,start_date=None,end_date=None):
    df_resched = get_df_span(df,start_date,end_date)
    df_recount = get_df_count(df,start_date,end_date,True)
    dates = df_recount.index
    
    for date in dates[:-1]:
        next_ = date + DAYS_1
        df_recount = get_df_count(df_resched,start_date,end_date,True)
        date_imb = get_imb(df_recount,date)
        next_imb = get_imb(df_recount,next_)
        
        if date_imb > 0:
            if date_imb < next_imb: # if there's more truck coming in tomorrow
                num_orders = int((next_imb - date_imb)/2)
                fr,to = date,next_

                cand = get_cand_orders(df_resched,fr,'Start Date',num_orders)
                for index in cand.index:
                    e_start,l_start,e_compl,l_compl = get_bound_dates(index).values()
                    if e_start <= to and to <= l_start:
                        df_resched = move(df_resched,index,to,col="Start Date")

            elif date_imb > next_imb:
                num_orders = int((date_imb - next_imb)/2)
                fr,to = next_,date

                cand = get_cand_orders(df_resched,fr,'Start Date',num_orders)
                for index in cand.index:
                    e_start,l_start,e_compl,l_compl = get_bound_dates(index).values()
                    if e_start <= to and to <= l_start:
                        df_resched = move(df_resched,index,to,col="Start Date")

        elif date_imb < 0: 
            if date_imb < next_imb: # if there's more truck coming in tomorrow
                num_orders = int((next_imb - date_imb)/2)
                fr,to = next_,date
                
                cand = get_cand_orders(df_resched,fr,'Completion Date',num_orders)
                for index in cand.index:
                    e_start,l_start,e_compl,l_compl = get_bound_dates(index).values()
                    if e_compl <= to and to <= l_compl:
                        df_resched = move(df_resched,index,to,col="Completion Date")

            elif date_imb > next_imb:
                num_orders = int((date_imb - next_imb)/2)
                fr,to = date,next_
                
                cand = get_cand_orders(df_resched,fr,'Completion Date',num_orders)
                for index in cand.index:
                    e_start,l_start,e_compl,l_compl = get_bound_dates(index).values()
                    if e_compl <= to and to <= l_compl:
                        df_resched = move(df_resched,index,to,col="Completion Date")
    return df_resched

# %%
start_date = pd.Timestamp(2020,1,1,0)
end_date = pd.Timestamp(2020,3,31,0)

df = DF_CLEAN
df_resched = get_df_rescheduled(df,start_date,end_date)
df_resched
# Out:
#        Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 4      Standard                     DRY          PQ2MON            USMWIA
# 15     Standard                     DRY          PQ2OTT            PQ2MON
# 16     Standard                     DRY          PQ2OTT            PQ2MON
# 26     Standard                     DRY          PQ2OTT              PQ2S
# 27     Standard                     DRY          PQ2OTT              PQ2S
# ...         ...                     ...             ...               ...
# 23833  Standard                     DRY          PQ2MON            BC2VAN
# 23834  Standard                     DRY          PQ2MON            USMEIS
# 23865  Standard                  REEFER          PQ2MON            ABNEDM
# 23866  Standard                  REEFER          PQ2MON            ABNEDM
# 23867  Standard                  REEFER          PQ2MON            ABNEDM
#
#       Start Date Completion Date
# 4     2020-02-26      2020-03-02
# 15    2019-12-30      2020-01-03
# 16    2020-02-17      2020-02-19
# 26    2020-01-13      2020-01-14
# 27    2020-01-21      2020-01-22
# ...          ...             ...
# 23833 2020-03-12      2020-03-19
# 23834 2020-02-04      2020-02-06
# 23865 2020-02-12      2020-02-18
# 23866 2020-02-12      2020-02-20
# 23867 2020-02-13      2020-02-18
#
# [2442 rows x 6 columns]

# %%
df_sched = get_df_span(df,start_date,end_date)
df_sched
# Out:
#        Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 4      Standard                     DRY          PQ2MON            USMWIA
# 15     Standard                     DRY          PQ2OTT            PQ2MON
# 16     Standard                     DRY          PQ2OTT            PQ2MON
# 26     Standard                     DRY          PQ2OTT              PQ2S
# 27     Standard                     DRY          PQ2OTT              PQ2S
# ...         ...                     ...             ...               ...
# 23833  Standard                     DRY          PQ2MON            BC2VAN
# 23834  Standard                     DRY          PQ2MON            USMEIS
# 23865  Standard                  REEFER          PQ2MON            ABNEDM
# 23866  Standard                  REEFER          PQ2MON            ABNEDM
# 23867  Standard                  REEFER          PQ2MON            ABNEDM
#
#       Start Date Completion Date
# 4     2020-02-26      2020-03-02
# 15    2019-12-30      2020-01-03
# 16    2020-02-18      2020-02-19
# 26    2020-01-13      2020-01-15
# 27    2020-01-21      2020-01-22
# ...          ...             ...
# 23833 2020-03-12      2020-03-19
# 23834 2020-02-04      2020-02-06
# 23865 2020-02-12      2020-02-18
# 23866 2020-02-12      2020-02-20
# 23867 2020-02-13      2020-02-18
#
# [2442 rows x 6 columns]

# %% [markdown]
# ## Analysis and Correctness

# %% [markdown]
# Get the orders that were rescheduled, and how they were rescheduled

# %%
df_diff = get_df_sched_diff(df_sched,df_resched)
df_diff
# Out:
#       Start Date Completion Date
# 16       -1 days          0 days
# 26        0 days         -1 days
# 28       -1 days          0 days
# 44       -1 days          0 days
# 46       -1 days          0 days
# ...          ...             ...
# 20969    -1 days          0 days
# 20970    -1 days          0 days
# 20972    -1 days          0 days
# 20993    -1 days          0 days
# 20994    -1 days          0 days
#
# [240 rows x 2 columns]

# %% [markdown]
# Before and After, side by side

# %%
df_sched.loc[df_diff.index].head(5)
# Out:
#     Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 16  Standard                     DRY          PQ2OTT            PQ2MON
# 26  Standard                     DRY          PQ2OTT              PQ2S
# 28  Standard                     DRY          PQ2OTT              PQ2S
# 44  Standard                     DRY          PQ2OTT            USMWNE
# 46  Standard                     DRY            PQ2S            USMWMO
#
#    Start Date Completion Date
# 16 2020-02-18      2020-02-19
# 26 2020-01-13      2020-01-15
# 28 2020-02-25      2020-02-27
# 44 2020-03-13      2020-03-16
# 46 2020-01-10      2020-01-13

# %%
df_resched.loc[df_diff.index].head(5)
# Out:
#     Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 16  Standard                     DRY          PQ2OTT            PQ2MON
# 26  Standard                     DRY          PQ2OTT              PQ2S
# 28  Standard                     DRY          PQ2OTT              PQ2S
# 44  Standard                     DRY          PQ2OTT            USMWNE
# 46  Standard                     DRY            PQ2S            USMWMO
#
#    Start Date Completion Date
# 16 2020-02-17      2020-02-19
# 26 2020-01-13      2020-01-14
# 28 2020-02-24      2020-02-27
# 44 2020-03-12      2020-03-16
# 46 2020-01-09      2020-01-13

# %% [markdown]
# Comparing the count of the old schedule vs the one for new schedule

# %%
df_count = get_df_count(df_sched)
df_count.head(5)
# Out:
#             Outbound  Inbound  Imbalance  cImbalance
# 2019-12-30         1        0         -1          -1
# 2020-01-01         3        0         -3          -4
# 2020-01-02         6       17         11           7
# 2020-01-03        18       14         -4           3
# 2020-01-04         7        1         -6          -3

# %%
df_recount = get_df_count(df_resched)
df_recount.head(5)
# Out:
#             Outbound  Inbound  Imbalance  cImbalance
# 2019-12-30         1        0         -1          -1
# 2020-01-01         3        7          4           3
# 2020-01-02        10       10          0           3
# 2020-01-03        14       14          0           3
# 2020-01-04         7        1         -6          -3

# %% [markdown]
# The changes made comapred to the original table

# %%
get_df_count_diff(df_count,df_recount).head(5)
# Out:
#             Outbound  Inbound  Imbalance  cImbalance
# 2020-01-01       0.0      7.0        7.0         7.0
# 2020-01-02       4.0     -7.0      -11.0        -4.0
# 2020-01-03      -4.0      0.0        4.0         0.0
# 2020-01-05       0.0      6.0        6.0         6.0
# 2020-01-06      -2.0     -6.0       -4.0         2.0

# %%
def plot_imb(df,marker='o',col="Imbalance"):
    firstDate = min(df.index)
    lastDate = max(df.index)
    plt.plot(df.index,df[col],marker)
    plt.plot([firstDate,lastDate],[0,0],'k-')

# %%
plt.figure(figsize=(15,8))
plot_imb(df_count)
plot_imb(df_recount)

# %%
def get_ci(series):
    mean = series.mean()
    std = series.std()
    return (mean-std,mean+std)

print(get_ci(df_count["Imbalance"]))
print(get_ci(df_recount["Imbalance"]))
# Out:
# (-4.287575665569294, 8.613662622091034)
# (-1.4600727019397763, 5.786159658461516)

# %%
df = DF_CLEAN
df_resched = get_df_rescheduled(df)

df_count = get_df_count(df)
df_recount = get_df_count(df_resched)

plt.figure(figsize=(15,8))
plot_imb(df_count)
plot_imb(df_recount)

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df_count,x="Imbalance",kde=True)
sns.histplot(data=df_recount,x="Imbalance",color="red",kde=True)
# Out:
# <AxesSubplot:xlabel='Imbalance', ylabel='Count'>

# %% [markdown]
# ## Our Strategy: Local Average

# %% [markdown]
# Idea:
#
# ```
# for day in all_days:
#     k_days_stack = imbalance_table[day:day+k]
#     # pick out the next sequence of k days, including today. This will be our stack
#     # (e.g if k=3, we pick out today, tomorrow and the day after tomorrow)
#
#     # Now we balance locally within the stack.
#     # Since we cannot just move around the imb anywhere we want, because of the dependencies involved,
#     # we will gradually balance each element in the stack (i.e make the imb level ~= stack_avg)
#     # by transferring the imb to the next day and pop the element from the stack
#
#     for stack_day in k_days_stack:
#         k_day_avg = k_next_days.avg
#         #take the average imbalance of the elements remaining in the stack
#         day_st = k.pop()
#         # pop the day at top of the stack
#         num_orders = k_day_avg - day_st.imb
#         cand_orders = get_cand_orders(day_st,num_orders)
#
#         #
#         # Insert code that  move num_orders from today to the next date
#         #
#
# ```

# %%
import random
from random import randint

random.seed(10)

# Not the real rescheduling algorithm, but can illustrate how the idea behind it works!
def local_k_average(org_list,k=2,randomized=False,verbose=False):
    new_list = np.array(org_list)
    for i in range(len(new_list)-(k-1)):
        if verbose: print('\nIteration',i,new_list,"sum =",new_list.sum())
            
        for j in range(i,i+k):
            avg = int(np.average(new_list[j:i+k]))
            num_orders = avg - new_list[j]
            if not randomized:
                actual_orders = num_orders
            elif randomized:
                if num_orders == 0: actual_orders # Avoid dividing by zero problem
                else: actual_orders = int(randint(0,abs(num_orders)) * (num_orders//abs(num_orders)))
            if verbose: print('Stack ({}):'.format(j-i),new_list[j:i+k],"avg =",avg,'\tday[{}] -[{}/{} ords]-> day[{}]'.format(j,actual_orders,num_orders,j+1))
            
            new_list[j] += actual_orders
            if j+1 < len(new_list): new_list[j+1] -= actual_orders
        if verbose: print('Result Stack: ',new_list[i:i+k])
               
    if verbose: 
        print('\nOriginally:',org_list,"\n sum =",org_list.sum(),"\n std=",org_list.std())
        print('Result:(k={})'.format(k),new_list,"\n sum =",new_list.sum(),"\n std=",new_list.std())
    return list(new_list)

# %%
# def print_report(series):
#     print()
#     m1,m2 = get_ci(series)
#     print("Series:",list(series))
#     print("CI (.84): [{:.2f},{:.2f}]".format(m1,m2))
#     print("Mean: {:.2f}".format(np.mean(series)))
#     print("Std: {:.2f}".format(np.std(series)))

# %%
start_date = pd.Timestamp(2020,1,1,0)
end_date = pd.Timestamp(2021,1,1,0)

df = get_df_span(DF_CLEAN,start_date,end_date)
df_count = get_df_count(df,start_date,end_date,True)
df_count
# Out:
#             Outbound  Inbound  Imbalance  cImbalance
# 2020-01-01         3        0         -3          -3
# 2020-01-02         6       17         11           8
# 2020-01-03        18       14         -4           4
# 2020-01-04         7        1         -6          -2
# 2020-01-05         7        1         -6          -8
# ...              ...      ...        ...         ...
# 2020-12-28        13       20          7         331
# 2020-12-29        18       17         -1         330
# 2020-12-30        21       18         -3         327
# 2020-12-31        15       23          8         335
# 2021-01-01         1        2          1         336
#
# [367 rows x 4 columns]

# %%
org_list = np.array(df_count["Imbalance"])
# new_list_2 = local_k_average(org_list,k=2,verbose=True)
# new_list_2 = local_k_average(org_list,k=3,verbose=True)
# new_list_2 = local_k_average(org_list,k=5,verbose=True)
# new_list_2 = local_k_average(org_list,k=6,verbose=True)
# new_list_2 = local_k_average(org_list,k=7,verbose=True)
# new_list_2 = local_k_average(org_list,k=7,verbose=True)
new_list_3 = local_k_average(org_list,k=7,verbose=False)
print(np.array(new_list_3).std())
# Out:
# 2.41948351244677

# %%
new_list_3 = local_k_average(org_list,k=28,verbose=False)
print(np.array(org_list).std())
print(np.array(new_list_3).std())
# Out:
# 7.184296656643084
# 1.4260915045197275

# %%
org_list = np.array(df_count["Imbalance"].head(10))
new_list_3 = local_k_average(org_list,k=3,verbose=False)
# new_list_4 = local_k_average(org_list,k=4,verbose=True)
# new_list_5 = local_k_average(org_list,k=5,verbose=True)

# %%
org_list = np.array(df_count["Imbalance"].head(10))
new_list_3 = local_k_average(org_list,k=4,verbose=False)

# %%
org_list = np.array(df_count["Imbalance"])
new_list_2 = local_k_average(org_list,k=2,verbose=False)
new_list_3 = local_k_average(org_list,k=3,verbose=False)
new_list_4 = local_k_average(org_list,k=4,verbose=False)
new_list_5 = local_k_average(org_list,k=5,verbose=False)
new_list_7 = local_k_average(org_list,k=7,verbose=False)
new_list_14 = local_k_average(org_list,k=14,verbose=False)
new_list_28 = local_k_average(org_list,k=28,verbose=False)
new_list_50 = local_k_average(org_list,k=50,verbose=False)

plt.figure(figsize=(15,8))
plt.plot(org_list,'o',label='Original',linewidth=2)
plt.plot(new_list_2,'o',label='Local Avg. k=2',linewidth=2)
plt.plot(new_list_3,'o',label='Local Avg. k=3',linewidth=2)
plt.plot([0,len(org_list)],[0,0],'k-')
plt.legend()
plt.show()

plt.figure(figsize=(15,8))
plt.plot(org_list,'o',label='Original',linewidth=2)
plt.plot(new_list_4,'mo',label='Local Avg. k=4',linewidth=2)
plt.plot(new_list_5,'co',label='Local Avg. k=5',linewidth=2)
plt.plot([0,len(org_list)],[0,0],'k-')
plt.legend()
plt.show()

plt.figure(figsize=(15,8))
plt.plot(org_list,'o',label='Original',linewidth=2)
plt.plot(new_list_7,'o',label='Local Avg. k=7',linewidth=2)
plt.plot(new_list_14,'o',label='Local Avg. k=14',linewidth=2)
plt.plot([0,len(org_list)],[0,0],'k-')
plt.legend()
plt.show()

plt.figure(figsize=(15,8))
plt.plot(org_list,'o',label='Original',linewidth=2)
plt.plot(new_list_28,'mo',label='Local Avg. k=28',linewidth=2)
plt.plot(new_list_50,'co',label='Local Avg. k=50',linewidth=2)
plt.plot([0,len(org_list)],[0,0],'k-')
plt.legend()
plt.show()

# %%
# Monte Carlo?!

# %%
org_list = np.array(df_count["Imbalance"].head(10))
new_list_3 = local_k_average(org_list,k=5,randomized=False,verbose=True)
# Out:
# Iteration 0 [-3 11 -4 -6 -6  7  5 -4  8 -6] sum = 2
# Stack (0): [-3 11 -4 -6 -6] avg = -1 	day[0] -[2/2 ords]-> day[1]
# Stack (1): [ 9 -4 -6 -6] avg = -1 	day[1] -[-10/-10 ords]-> day[2]
# Stack (2): [ 6 -6 -6] avg = -2 	day[2] -[-8/-8 ords]-> day[3]
# Stack (3): [ 2 -6] avg = -2 	day[3] -[-4/-4 ords]-> day[4]
# Stack (4): [-2] avg = -2 	day[4] -[0/0 ords]-> day[5]
# Result Stack:  [-1 -1 -2 -2 -2]
#
# Iteration 1 [-1 -1 -2 -2 -2  7  5 -4  8 -6] sum = 2
# Stack (0): [-1 -2 -2 -2  7] avg = 0 	day[1] -[1/1 ords]-> day[2]
# Stack (1): [-3 -2 -2  7] avg = 0 	day[2] -[3/3 ords]-> day[3]
# Stack (2): [-5 -2  7] avg = 0 	day[3] -[5/5 ords]-> day[4]
# Stack (3): [-7  7] avg = 0 	day[4] -[7/7 ords]-> day[5]
# Stack (4): [0] avg = 0 	day[5] -[0/0 ords]-> day[6]
# Result Stack:  [0 0 0 0 0]
#
# Iteration 2 [-1  0  0  0  0  0  5 -4  8 -6] sum = 2
# Stack (0): [0 0 0 0 5] avg = 1 	day[2] -[1/1 ords]-> day[3]
# Stack (1): [-1  0  0  5] avg = 1 	day[3] -[2/2 ords]-> day[4]
# Stack (2): [-2  0  5] avg = 1 	day[4] -[3/3 ords]-> day[5]
# Stack (3): [-3  5] avg = 1 	day[5] -[4/4 ords]-> day[6]
# Stack (4): [1] avg = 1 	day[6] -[0/0 ords]-> day[7]
# Result Stack:  [1 1 1 1 1]
#
# Iteration 3 [-1  0  1  1  1  1  1 -4  8 -6] sum = 2
# Stack (0): [ 1  1  1  1 -4] avg = 0 	day[3] -[-1/-1 ords]-> day[4]
# Stack (1): [ 2  1  1 -4] avg = 0 	day[4] -[-2/-2 ords]-> day[5]
# Stack (2): [ 3  1 -4] avg = 0 	day[5] -[-3/-3 ords]-> day[6]
# Stack (3): [ 4 -4] avg = 0 	day[6] -[-4/-4 ords]-> day[7]
# Stack (4): [0] avg = 0 	day[7] -[0/0 ords]-> day[8]
# Result Stack:  [0 0 0 0 0]
#
# Iteration 4 [-1  0  1  0  0  0  0  0  8 -6] sum = 2
# Stack (0): [0 0 0 0 8] avg = 1 	day[4] -[1/1 ords]-> day[5]
# Stack (1): [-1  0  0  8] avg = 1 	day[5] -[2/2 ords]-> day[6]
# Stack (2): [-2  0  8] avg = 2 	day[6] -[4/4 ords]-> day[7]
# Stack (3): [-4  8] avg = 2 	day[7] -[6/6 ords]-> day[8]
# Stack (4): [2] avg = 2 	day[8] -[0/0 ords]-> day[9]
# Result Stack:  [1 1 2 2 2]
#
# Iteration 5 [-1  0  1  0  1  1  2  2  2 -6] sum = 2
# Stack (0): [ 1  2  2  2 -6] avg = 0 	day[5] -[-1/-1 ords]-> day[6]
# Stack (1): [ 3  2  2 -6] avg = 0 	day[6] -[-3/-3 ords]-> day[7]
# Stack (2): [ 5  2 -6] avg = 0 	day[7] -[-5/-5 ords]-> day[8]
# Stack (3): [ 7 -6] avg = 0 	day[8] -[-7/-7 ords]-> day[9]
# Stack (4): [1] avg = 1 	day[9] -[0/0 ords]-> day[10]
# Result Stack:  [0 0 0 0 1]
#
# Originally: [-3 11 -4 -6 -6  7  5 -4  8 -6]
#  sum = 2
#  std= 6.384355879804947
# Result:(k=5) [-1  0  1  0  1  0  0  0  0  1]
#  sum = 2
#  std= 0.6000000000000001

# %% [markdown]
# ## How to choose the candidates?

# %%
random.seed(10)
min_val = 0
max_val = 20

df = pd.DataFrame()
df['Inbound'] = np.array([randint(min_val,max_val) for i in range(15)])
df['Outbound'] = np.array([randint(min_val,max_val) for i in range(15)])
df['Imbalance'] = df['Inbound'] - df['Outbound']
df
# Out:
#     Inbound  Outbound  Imbalance
# 0        18        10          8
# 1         1         2         -1
# 2        13         7          6
# 3        15        11          4
# 4        18         1         17
# 5         0        13        -13
# 6         6         4          2
# 7        14        19         -5
# 8        15        11          4
# 9         8        12         -4
# 10       20        13          7
# 11        5         9         -4
# 12        1         8         -7
# 13       16        14          2
# 14       15         5         10

# %% [markdown]
# Now I would like to address the problem of picking the candidates for balancing
#
# For 2 days curr(in1,out1) and next(in2,out2), given a target imbalance value bal_val, how should we achieve d_bal such that  curr.imb + d_bal = bal_val? How many inbound order do we move in between curr and next, and how many outbound orders?
#
# For example between Day 0 and 1, d_bal = -5. We can add 5 more outbound orders (by taking in from next), or reduce 5 inbound orders (by deffering to next). But is it always a good case to do so? Is it even possible anyways?
#
# IF we look at Day 0 and Day 1, there is significantly more traffic in and out of Day 0 (18,10), and barely anything on Day 1 (1,2). It works if our strategy choose to defer the 5 inbound trailers, so it becomes (13,10) and (7,2), but it wouldn't make sense to go the other way: (18,15), (1,-2). We want something flexible

# %%
# balance_demo(df,0,1,verbose=True)
# balance_demo(df,4,5,verbose=True)
# balance_demo(df,9,10,verbose=True)
# balance_demo(df,12,13,verbose=True)

# %%
def balance_demo(df,day1,day2,bal_val=None,verbose=False):
    df1 = df.copy()
    if verbose: 
        print("\nDay:",df1.index[day1])
        print("Before:\n",df1.loc[[day1,day2]])
    
    if bal_val == None: 
        bal_val = int(np.average(df1.loc[[day1,day2],"Imbalance"]))
    in1,in2 = df1.loc[[day1,day2],"Inbound"]
    out1,out2 = df1.loc[[day1,day2],"Outbound"]
    d_bal = bal_val - df1.loc[day1,"Imbalance"]   

    if d_bal > 0: # If we need to add more incoming traffic/ reducing outgoing traffic
        if (in1 > in2 and out1 > out2): # if traffic is heavier today, we prioritize reducing outbound traffic
            d_out = move_ord_(df1,"Outbound",day1,day2,d_bal) # We defer as many outbound orders to tomorrow as possible
            d_in = move_ord_(df1,"Inbound",day2,day1,d_bal-d_out) # If it's not enough then we make up by taking in tomorrow's completion

        elif (in1 < in2 and out1 < out2): # if traffic is less today, we prioritize increasing inbound traffic 
            d_in = move_ord_(df1,"Inbound",day2,day1,d_bal) # We take in as many inbound orders from tomorrow as possible
            d_out = move_ord_(df1,"Outbound",day1,day2,d_bal-d_in) # If it's not enough then we make up by deferring the outbound order til tomorrow

        else: # else we split the order between moving the start date and completion date 
            d_in = move_ord_(df1,"Inbound",day2,day1,d_bal//2) # Try to see if we can take in some inbound order
            d_out = move_ord_(df1,"Outbound",day1,day2,d_bal-d_in) # Then try to see if we can defer the outbound orders 
            d_in += move_ord_(df1,"Inbound",day2,day1,d_bal-(d_in+d_out)) # Just in case after the first 2 steps, there's still job to be moved

    elif d_bal < 0:  # If we need to reduce incoming traffic/ increase outbound traffic
        d_bal = abs(d_bal)
        if (in1 > in2 and out1 > out2): # if traffic is heavier today, we prioritize reducing inbound traffic
            d_in = move_ord_(df1,"Inbound",day1,day2,d_bal) # We defer as many inbound orders to tomorrow as possible
            d_out = move_ord_(df1,"Outbound",day2,day1,d_bal-d_in) # If it's not enough then we make up by taking in the outbound order from tomorrow

        elif (in1 < in2 and out1 < out2): # if traffic is less today, we prioritize increasing outbound traffic 
            d_out = move_ord_(df1,"Outbound",day2,day1,d_bal) # We take in as many outbound orders from tomorrow as possible
            d_in = move_ord_(df1,"Inbound",day1,day2,d_bal-d_out) # If it's not enough then we make up by deferring some inbound truck to tomorrow

        else: # else we split the order between moving the start date and completion date 
            d_in = move_ord_(df1,"Inbound",day1,day2,d_bal//2) # We defer as many inbound orders to tomorrow as possible
            d_out = move_ord_(df1,"Outbound",day2,day1,d_bal-d_in) # If it's not enough then we make up by taking in the outbound order from tomorrow
            d_in += move_ord_(df1,"Inbound",day1,day2,d_bal-(d_in+d_out)) # We defer as many inbound orders to tomorrow as possible
        d_bal *= -1
        d_in *= -1

    if verbose:
        print("d_bal =",d_bal,": d_in =",d_in, "d_out =", d_out)
        print("After:\n",df1.loc[[day1,day2]],'\n')
        
    return df1

def move_ord_(df,col,fr,to,num_ord):
    actual_ord = int(min(df.loc[fr,col],num_ord))
    df.loc[fr,col] -= actual_ord
    df.loc[to,col] += actual_ord
    df.loc[fr,"Imbalance"] = df.loc[fr,"Inbound"] - df.loc[fr,"Outbound"]
    df.loc[to,"Imbalance"] = df.loc[to,"Inbound"] - df.loc[to,"Outbound"]
    return actual_ord

# %%
df1 = df.copy()

for i in range(len(df1.index[:-1])):
    df1 = balance_demo(df1,df1.index[i],df1.index[i+1],verbose=False)
    
pd.concat([df,df1],axis=1)
# Out:
#     Inbound  Outbound  Imbalance  Inbound  Outbound  Imbalance
# 0        18        10          8       13        10          3
# 1         1         2         -1        7         2          5
# 2        13         7          6       12         8          4
# 3        15        11          4       18         7         11
# 4        18         1         17        9        10         -1
# 5         0        13        -13        6         6          0
# 6         6         4          2        6         8         -2
# 7        14        19         -5       15        14          1
# 8        15        11          4       12        13         -1
# 9         8        12         -4       14        12          2
# 10       20        13          7       13        13          0
# 11        5         9         -4        5         9         -4
# 12        1         8         -7        7         8         -1
# 13       16        14          2       15        11          4
# 14       15         5         10       13         8          5

# %%
df2 = df_count.head(20)

for i in range(len(df2.index[:-1])):
    df2 = balance_demo(df2,df2.index[i],df2.index[i+1],verbose=False)
    
pd.concat([df_count.head(20),df2],axis=1)
# Out:
#             Outbound  Inbound  Imbalance  cImbalance  Outbound  Inbound  \
# 2019-12-30         1        0         -1          -1         2        0
# 2020-01-01         3        0         -3          -4         2        6
# 2020-01-02         6       17         11           7        11       11
# 2020-01-03        18       14         -4           3        13       11
# 2020-01-04         7        1         -6          -3         8        4
# 2020-01-05         7        1         -6          -9         6        7
# 2020-01-06        17       24          7          -2        16       19
# 2020-01-07        14       19          5           3        17       17
# 2020-01-08        15       11         -4          -1        11       14
# 2020-01-09        12       20          8           7        17       16
# 2020-01-10        22       16         -6           1        19       15
# 2020-01-11         9        1         -8          -7         7        4
# 2020-01-12         5        3         -2          -9         7        7
# 2020-01-13        15       19          4          -5        17       14
# 2020-01-14        17       11         -6         -11        13       12
# 2020-01-15         0        1          1         -10         2        1
#
#             Imbalance  cImbalance
# 2019-12-30         -2          -1
# 2020-01-01          4          -4
# 2020-01-02          0           7
# 2020-01-03         -2           3
# 2020-01-04         -4          -3
# 2020-01-05          1          -9
# 2020-01-06          3          -2
# 2020-01-07          0           3
# 2020-01-08          3          -1
# 2020-01-09         -1           7
# 2020-01-10         -4           1
# 2020-01-11         -3          -7
# 2020-01-12          0          -9
# 2020-01-13         -3          -5
# 2020-01-14         -1         -11
# 2020-01-15         -1         -10

# %%
def balance(df,day1,day2,bal_val=None,verbose=False):
    df1 = df.copy()
    df_count = get_df_count(df1)
    
    if verbose: 
        print("\nDay:",day1)
        print("Before:\n",df_count.loc[[day1,day2]])
    
    if bal_val == None: 
        bal_val = int(np.average(df_count.loc[[day1,day2],"Imbalance"]))
    in1,in2 = df_count.loc[[day1,day2],"Inbound"]
    out1,out2 = df_count.loc[[day1,day2],"Outbound"]
    d_bal = bal_val - df_count.loc[day1,"Imbalance"]
    d_out,d_in1,d_in2= 0,0,0
    
    if d_bal > 0:
        if (in1 > in2 and out1 > out2): # if traffic is heavier today, we prioritize reducing outbound traffic
            df1,d_out = try_move_orders(df1,"Start Date",day1,day2,num_orders = d_bal) # We defer as many outbound orders to tomorrow as possible
            df1,d_in1 = try_move_orders(df1,"Completion Date",day2,day1,num_orders = d_bal-d_out) # If it's not enough then we make up by taking in tomorrow's completion
         
        elif (in1 < in2 and out1 < out2): # if traffic is less today, we prioritize increasing inbound traffic 
            df1,d_in1 = try_move_orders(df1,"Completion Date",day2,day1,d_bal) # We take in as many inbound orders from tomorrow as possible
            df1,d_out = try_move_orders(df1,"Start Date",day1,day2,d_bal-d_in1) # If it's not enough then we make up by deferring the outbound order til tomorrow

        else: # If inbound and outbound traffic comparison is mixed, we pick half each type to even everything out 
            df1,d_in1 = try_move_orders(df1,"Completion Date",day2,day1,d_bal//2) # Try to see if we can take in some inbound order
            df1,d_out = try_move_orders(df1,"Start Date",day1,day2,d_bal-d_in1) # Then try to see if we can defer the outbound orders 
            df1,d_in2 = try_move_orders(df1,"Completion Date",day2,day1,d_bal-(d_in1+d_out)) # Just in case after the first 2 steps, there's still job to be moved

    elif d_bal < 0:  # If we need to reduce incoming traffic/ increase outbound traffic
        d_bal = abs(d_bal)
        if (in1 > in2 and out1 > out2): # if traffic is heavier today, we prioritize reducing inbound traffic
            df1,d_in1 = try_move_orders(df1,"Completion Date",day1,day2,d_bal) # We defer as many inbound orders to tomorrow as possible
            df1,d_out = try_move_orders(df1,"Start Date",day2,day1,d_bal-d_in1) # If it's not enough then we make up by taking in the outbound order from tomorrow

        elif (in1 < in2 and out1 < out2): # if traffic is less today, we prioritize increasing outbound traffic 
            df1,d_out = try_move_orders(df1,"Start Date",day2,day1,d_bal) # We take in as many outbound orders from tomorrow as possible
            df1,d_in1 = try_move_orders(df1,"Completion Date",day1,day2,d_bal-d_out) # If it's not enough then we make up by deferring some inbound truck to tomorrow

        else: # If inbound and outbound traffic comparison is mixed, we pick half each type to even everything out 
            df1,d_in1 = try_move_orders(df1,"Completion Date",day1,day2,d_bal//2) # We defer inbound orders to tomorrow as possible
            df1,d_out = try_move_orders(df1,"Start Date",day2,day1,d_bal-d_in1) # If it's not enough then we make up by taking in the outbound order from tomorrow
            df1,d_in2 = try_move_orders(df1,"Completion Date",day1,day2,d_bal-(d_in1+d_out)) # We defer as many inbound orders to tomorrow as possible
        d_bal *= -1
        d_in1 *= -1
        d_in2 *= -1
    
    df_count = get_df_count(df1)
    if verbose:
        print("d_bal =",d_bal,": d_in =",d_in1+d_in2, "d_out =", d_out)
        print("After:\n",df_count.loc[[day1,day2]],'\n')

    return df1
        
def try_move_orders(df,col,day1,day2,num_orders=None):
    df1 = df.copy()
    df_all_orders = get_df_day(df1,day1,col).sort_values(by=["Start Date","Completion Date"],ascending=False) # List of all Outbound/Inbound orders, longest duration first
    df_movable_orders = get_df_movable(df_all_orders,col,day2)
    if num_orders == None or num_orders < 0: 
        num_orders = len(df_all_orders)
    df_movable_orders = df_movable_orders[:num_orders]
    for index in df_movable_orders.index:
        assert(df1.loc[index,col] == day1)
        df1 = move(df1,index,day2,col) # Move order to day2
    return df1, len(df_movable_orders)   
    
def get_df_movable(df,col,day):
    mov = [] 
    for index in df.index:
        if (movable(col,index,day)):
            mov.append(index)
    return df.loc[mov]

    # Can we move the Start/Completion Date of the item at index to this day?
def movable(col,index,day):
    e_start,l_start,e_compl,l_compl = get_bound_dates(index).values()
    if col == 'Start Date': return day <= l_start #or day >= e_start
    elif col == 'Completion Date': return day >= e_compl and day <= l_compl

# %%
# Demo balance()
date = pd.Timestamp(2020,12,24,0)
df = get_df_span(DF_CLEAN,date,date+7*DAYS_1)
df_count = get_df_count(df)
df_count
# Out:
#             Outbound  Inbound  Imbalance  cImbalance
# 2020-12-22         2        0         -2          -2
# 2020-12-24        10       16          6           4
# 2020-12-25         3        6          3           7
# 2020-12-26         7       11          4          11
# 2020-12-27        11        6         -5           6
# 2020-12-28        13       20          7          13
# 2020-12-29        18       17         -1          12
# 2020-12-30        21       18         -3           9
# 2020-12-31        15       23          8          17
# 2021-01-04         0        1          1          18

# %%
# Demo balance()...
day1 = df_count.index[3]
day2 = df_count.index[4]

balance(df,day1,day2,verbose=True)
# Out:
# Day: 2020-12-26 00:00:00
# Before:
#              Outbound  Inbound  Imbalance  cImbalance
# 2020-12-26         7       11          4          11
# 2020-12-27        11        6         -5           6
# d_bal = -4 : d_in = -2 d_out = 2
# After:
#              Outbound  Inbound  Imbalance  cImbalance
# 2020-12-26         9        9          0           7
# 2020-12-27         9        8         -1           6
#         Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 517     Standard                     DRY           USEAC            PQ2MON
# 1287    Standard                  REEFER          ON2TOR            PQ2MON
# 1288    Standard                  REEFER          ON2TOR            PQ2MON
# 1289    Standard                  REEFER          ON2TOR            PQ2MON
# 1290    Standard                  REEFER          ON2TOR            PQ2MON
# ...          ...                     ...             ...               ...
# 22856  Expedited                  HEATER          PQ2MON            ABSCAL
# 22898  Expedited                  HEATER          PQ2MON            BC2VAN
# 23466   Standard                  REEFER            PQ2S            USMEON
# 23482   Standard                  REEFER            PQ2S            USMEON
# 23494   Standard                  REEFER            PQ2S            USMEON
#
#       Start Date Completion Date
# 517   2020-12-27      2020-12-30
# 1287  2020-12-23      2020-12-24
# 1288  2020-12-29      2020-12-30
# 1289  2020-12-30      2020-12-30
# 1290  2020-12-30      2020-12-31
# ...          ...             ...
# 22856 2020-12-29      2021-01-03
# 22898 2020-12-24      2020-12-30
# 23466 2020-12-28      2020-12-30
# 23482 2020-12-31      2021-01-04
# 23494 2020-12-28      2020-12-30
#
# [204 rows x 6 columns]

# %%
#Demo
# df = get_df_span(DF_CLEAN,start_date,end_date)
# col = 'Completion Date'
# date = end_date - 6*DAYS_1
# df_day = get_df_day(df,date,col).sort_values(by=["Start Date","Completion Date"],ascending=True)
# df_day

# %%
# date -= DAYS_1
# print(date)
# get_df_movable(df_day,"Completion Date",date)

# %%
#Demo try_move_orders
start_date = pd.Timestamp(2020,1,1,0)
end_date = pd.Timestamp(2020,1,14,0)

df = get_df_span(DF_CLEAN,start_date,end_date)
df_count = get_df_count(df)
df_count
# Out:
#             Outbound  Inbound  Imbalance  cImbalance
# 2019-12-30         1        0         -1          -1
# 2020-01-01         3        0         -3          -4
# 2020-01-02         6       17         11           7
# 2020-01-03        18       14         -4           3
# 2020-01-04         7        1         -6          -3
# 2020-01-05         7        1         -6          -9
# 2020-01-06        17       24          7          -2
# 2020-01-07        14       19          5           3
# 2020-01-08        15       11         -4          -1
# 2020-01-09        12       20          8           7
# 2020-01-10        22       16         -6           1
# 2020-01-11         9        1         -8          -7
# 2020-01-12         5        3         -2          -9
# 2020-01-13        15       19          4          -5
# 2020-01-14        17       11         -6         -11
# 2020-01-15         0        1          1         -10

# %%
day1 = pd.Timestamp(2020,1,9,0)
day2 = pd.Timestamp(2020,1,10,0)

df1,a = try_move_orders(df,"Start Date",day1,day2)
print(a)
df1
# Out:
# 11
#        Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 15     Standard                     DRY          PQ2OTT            PQ2MON
# 26     Standard                     DRY          PQ2OTT              PQ2S
# 46     Standard                     DRY            PQ2S            USMWMO
# 58     Standard                     DRY          USMNMI              PQ2S
# 147    Standard                  REEFER          USEASE            PQ2MON
# ...         ...                     ...             ...               ...
# 23270  Standard                     DRY          PQ2MON            USSCTN
# 23271  Standard                     DRY          PQ2MON            USSCTN
# 23272  Standard                     DRY          PQ2MON            USSCTN
# 23273  Standard                     DRY          PQ2MON            USSCTN
# 23525  Standard                     DRY          PQ2MON            USEAEA
#
#       Start Date Completion Date
# 15    2019-12-30      2020-01-03
# 26    2020-01-13      2020-01-15
# 46    2020-01-10      2020-01-13
# 58    2020-01-03      2020-01-07
# 147   2020-01-13      2020-01-14
# ...          ...             ...
# 23270 2020-01-03      2020-01-08
# 23271 2020-01-10      2020-01-14
# 23272 2020-01-10      2020-01-14
# 23273 2020-01-13      2020-01-21
# 23525 2020-01-10      2020-01-13
#
# [319 rows x 6 columns]

# %%
df.loc[get_df_sched_diff(df,df1).index]
# Out:
#         Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 10980   Standard                  HEATER          PQ2MON            MB2WIN
# 12403   Standard                     DRY          PQ2MON              ON2S
# 12507   Standard                     DRY            PQ2S            USNWWA
# 15036   Standard                     DRY          PQ2MON            BC2ISL
# 15037   Standard                     DRY          PQ2MON            BC2ISL
# 16643   Standard                  HEATER          PQ2MON            USMEON
# 16972  Expedited                     DRY          PQ2MON            ABSCAL
# 17501  Expedited                     DRY          PQ2MON            MB2WIN
# 18471   Standard                     DRY          PQ2MON            USILCH
# 19872   Standard                  REEFER          PQ2MON            MB2WIN
# 23271   Standard                     DRY          PQ2MON            USSCTN
#
#       Start Date Completion Date
# 10980 2020-01-09      2020-01-16
# 12403 2020-01-09      2020-01-13
# 12507 2020-01-09      2020-01-20
# 15036 2020-01-09      2020-01-22
# 15037 2020-01-09      2020-01-21
# 16643 2020-01-09      2020-01-14
# 16972 2020-01-09      2020-01-13
# 17501 2020-01-09      2020-01-11
# 18471 2020-01-09      2020-01-13
# 19872 2020-01-09      2020-01-13
# 23271 2020-01-09      2020-01-14

# %%
get_df_day(df,col="Start Date",date=day1)
# Out:
#         Priority Requested Trailer Class Shipper Region3 Consignee Region3  \
# 10754   Standard                  REEFER          PQ2MON            ON2TOR
# 10980   Standard                  HEATER          PQ2MON            MB2WIN
# 12403   Standard                     DRY          PQ2MON              ON2S
# 12507   Standard                     DRY            PQ2S            USNWWA
# 15036   Standard                     DRY          PQ2MON            BC2ISL
# 15037   Standard                     DRY          PQ2MON            BC2ISL
# 16643   Standard                  HEATER          PQ2MON            USMEON
# 16972  Expedited                     DRY          PQ2MON            ABSCAL
# 17501  Expedited                     DRY          PQ2MON            MB2WIN
# 18471   Standard                     DRY          PQ2MON            USILCH
# 19872   Standard                  REEFER          PQ2MON            MB2WIN
# 23271   Standard                     DRY          PQ2MON            USSCTN
#
#       Start Date Completion Date
# 10754 2020-01-09      2020-01-09
# 10980 2020-01-09      2020-01-16
# 12403 2020-01-09      2020-01-13
# 12507 2020-01-09      2020-01-20
# 15036 2020-01-09      2020-01-22
# 15037 2020-01-09      2020-01-21
# 16643 2020-01-09      2020-01-14
# 16972 2020-01-09      2020-01-13
# 17501 2020-01-09      2020-01-11
# 18471 2020-01-09      2020-01-13
# 19872 2020-01-09      2020-01-13
# 23271 2020-01-09      2020-01-14
